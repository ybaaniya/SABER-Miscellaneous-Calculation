# %%
import os
import pandas as pd
import numpy as np
import xarray as xr

COL_QSIM = 'Q_sim'  # Simulated flow column

def load_zarr_data(hz_path: str) -> xr.Dataset:
    """ Load Zarr dataset containing river flow data. """
    return xr.open_mfdataset(hz_path, concat_dim='rivid', combine='nested', parallel=True, engine='zarr')

def extract_river_flow(hz: xr.Dataset, rivid: int) -> pd.DataFrame:
    """ Extract time series flow data for a given rivid from the Zarr dataset. """
    sim_flow = hz['Qout'][:, hz.rivid.values == rivid].values
    sim_flow_df = pd.DataFrame(sim_flow, index=hz['time'].values, columns=[COL_QSIM])
    return sim_flow_df

def fdc(flows: np.array, steps: int = 101) -> pd.DataFrame:
    """ Compute flow duration curve (FDC) from flow data. """
    exceed_prob = np.linspace(0, 100, steps)
    fdc_flows = np.nanpercentile(flows, exceed_prob)
    df = pd.DataFrame({'p_exceed': exceed_prob, 'fdc': fdc_flows})
    return df

def compute_monthly_fdcs(hz_path: str, output_file: str = None, num_rivids: int = None):
    """ Compute monthly flow duration curves for each rivid and save or display results. """
    hz = load_zarr_data(hz_path)
    rivids = hz.rivid.values  # Get all river IDs in the dataset
    
    if num_rivids is not None:
        rivids = rivids[:num_rivids]
    print(f"Total rivids being processed: {len(rivids)}")
    
    all_fdc_data = []
    
    for rivid in rivids:
        print(f"Processing rivid: {rivid}")
        sim_flow_df = extract_river_flow(hz, rivid)
        sim_flow_df.index = pd.to_datetime(sim_flow_df.index)
        # Apply the year filter for the range 1941-2025
        sim_flow_df = sim_flow_df[(sim_flow_df.index.year >= 1941) & (sim_flow_df.index.year <= 2025)]
        
        for month in range(1, 13):
            monthly_flow = sim_flow_df[sim_flow_df.index.month == month].dropna().clip(lower=0)
            #print(monthly_flow)
            if not monthly_flow.empty:
                #print(f"  - Processing month: {month} for rivid {rivid} with {len(monthly_flow)} records")
                fdc_df = fdc(monthly_flow[COL_QSIM].values)
                fdc_df['rivid'] = rivid
                fdc_df['Month'] = month
                all_fdc_data.append(fdc_df)
            else:
                print(f"  - No data for rivid {rivid} in month {month}")

    all_fdc_df = pd.concat(all_fdc_data, ignore_index=True)
    
    if output_file:
        all_fdc_df.to_parquet(output_file)
        #print(f'Saved FDC data to {output_file}')
    else:
        print(all_fdc_df)
    
    hz.close()

# Usage
hz_path = "/Users/yubinbaaniya/Documents/WORLD BIAS/saber workdir/2nd_iteration_simulation_data.zarr"  # Replace with the path to your Zarr file
output_file = "/Users/yubinbaaniya/Documents/WORLD BIAS/saber workdir/tables/monthly_simulated_FDC.parquet"  # Set to None if you don't want to save to a file during testing
num_rivids = None  # mention number of rivids for testing or None for using all rivids

compute_monthly_fdcs(hz_path, output_file=output_file, num_rivids=num_rivids)
# Out:
# Total rivids being processed: 19272
# Processing rivid: 110099693
# Processing rivid: 110149488
# Processing rivid: 110206983
# Processing rivid: 110207080
# Processing rivid: 110220341
# Processing rivid: 110231984
# Processing rivid: 110247633
# Processing rivid: 110252406
# Processing rivid: 110275139
# Processing rivid: 110284460
# Processing rivid: 110287075
# Processing rivid: 110296320
# Processing rivid: 110306692
# Processing rivid: 110310578
# Processing rivid: 110313194
# Processing rivid: 110314726
# Processing rivid: 110315855
# Processing rivid: 110325014
# Processing rivid: 110326327
# Processing rivid: 110330340
# Processing rivid: 110334201
# Processing rivid: 110351299
# Processing rivid: 110357907
# Processing rivid: 110384112
# Processing rivid: 110392033
# Processing rivid: 110394507
# Processing rivid: 110397166
# Processing rivid: 110397259
# Processing rivid: 110410366
# Processing rivid: 110414341
# Processing rivid: 110415641
# Processing rivid: 110418244
# Processing rivid: 110418274
# Processing rivid: 110426145
# Processing rivid: 110430065
# Processing rivid: 110431394
# Processing rivid: 110433973
# Processing rivid: 110437412
# Processing rivid: 110445826
# Processing rivid: 110453648
# Processing rivid: 110466796
# Processing rivid: 110466799
# Processing rivid: 110468071
# Processing rivid: 110469439
# Processing rivid: 110473373
# Processing rivid: 110479908
# Processing rivid: 110485159
# Processing rivid: 110487780
# Processing rivid: 110489086
# Processing rivid: 110507453
# Processing rivid: 110510083
# Processing rivid: 110520556
# Processing rivid: 110528426
# Processing rivid: 110546807
# Processing rivid: 110835013
# Processing rivid: 110846804
# Processing rivid: 110882243
# Processing rivid: 110884878
# Processing rivid: 120034971
# Processing rivid: 120041636
# Processing rivid: 120048223
# Processing rivid: 120048307
# Processing rivid: 120049932
# Processing rivid: 120049956
# Processing rivid: 120051623
# Processing rivid: 120064803
# Processing rivid: 120065019
# Processing rivid: 120068246
# Processing rivid: 120068285
# Processing rivid: 120069941
# Processing rivid: 120069950
# Processing rivid: 120074842
# Processing rivid: 120075002
# Processing rivid: 120078310
# Processing rivid: 120078334
# Processing rivid: 120084989
# Processing rivid: 120099781
# Processing rivid: 120099801
# Processing rivid: 120101641
# Processing rivid: 120104932
# Processing rivid: 120104942
# Processing rivid: 120116419
# Processing rivid: 120118102
# Processing rivid: 120118290
# Processing rivid: 120119735
# Processing rivid: 120119755
# Processing rivid: 120124745
# Processing rivid: 120141374
# Processing rivid: 120143052
# Processing rivid: 120154700
# Processing rivid: 120159680
# Processing rivid: 120159689
# Processing rivid: 120161337
# Processing rivid: 120161355
# Processing rivid: 120163016
# Processing rivid: 120167990
# Processing rivid: 120168007
# Processing rivid: 120172980
# Processing rivid: 120173000
# Processing rivid: 120174621
# Processing rivid: 120174656
# Processing rivid: 120176326
# Processing rivid: 120179654
# Processing rivid: 120179657
# Processing rivid: 120181539
# Processing rivid: 120182988
# Processing rivid: 120183204
# Processing rivid: 120184607
# Processing rivid: 120184645
# Processing rivid: 120186229
# Processing rivid: 120186305
# Processing rivid: 120187923
# Processing rivid: 120191267
# Processing rivid: 120202910
# Processing rivid: 120204526
# Processing rivid: 120204615
# Processing rivid: 120206510
# Processing rivid: 120207906
# Processing rivid: 120207936
# Processing rivid: 120209594
# Processing rivid: 120209597
# Processing rivid: 120212929
# Processing rivid: 120212930
# Processing rivid: 120214552
# Processing rivid: 120214571
# Processing rivid: 120214585
# Processing rivid: 120217917
# Processing rivid: 120219509
# Processing rivid: 120219578
# Processing rivid: 120221213
# Processing rivid: 120225893
# Processing rivid: 120227834
# Processing rivid: 120234809
# Processing rivid: 120237875
# Processing rivid: 120239542
# Processing rivid: 120239551
# Processing rivid: 120240082
# Processing rivid: 120242852
# Processing rivid: 120244522
# Processing rivid: 120246157
# Processing rivid: 120246182
# Processing rivid: 120247823
# Processing rivid: 120247858
# Processing rivid: 120248115
# Processing rivid: 120251116
# Processing rivid: 120251128
# Processing rivid: 120252856
# Processing rivid: 120256155
# Processing rivid: 120257769
# Processing rivid: 120262817
# Processing rivid: 120262827
# Processing rivid: 120264487
# Processing rivid: 120269482
# Processing rivid: 120276127
# Processing rivid: 120276134
# Processing rivid: 120279435
# Processing rivid: 120281075
# Processing rivid: 120282757
# Processing rivid: 120282765
# Processing rivid: 120284423
# Processing rivid: 120288062
# Processing rivid: 120291099
# Processing rivid: 120291109
# Processing rivid: 120292732
# Processing rivid: 120292758
# Processing rivid: 120294451
# Processing rivid: 120296113
# Processing rivid: 120297463
# Processing rivid: 120297718
# Processing rivid: 120297743
# Processing rivid: 120299347
# Processing rivid: 120299389
# Processing rivid: 120307738
# Processing rivid: 120308215
# Processing rivid: 120311033
# Processing rivid: 120312741
# Processing rivid: 120313938
# Processing rivid: 120314322
# Processing rivid: 120314342
# Processing rivid: 120319688
# Processing rivid: 120322676
# Processing rivid: 120324332
# Processing rivid: 120325561
# Processing rivid: 120327117
# Processing rivid: 120327626
# Processing rivid: 120329279
# Processing rivid: 120329334
# Processing rivid: 120329345
# Processing rivid: 120330554
# Processing rivid: 120330953
# Processing rivid: 120330989
# Processing rivid: 120334804
# Processing rivid: 120335812
# Processing rivid: 120336018
# Processing rivid: 120337654
# Processing rivid: 120338002
# Processing rivid: 120339282
# Processing rivid: 120339302
# Processing rivid: 120340564
# Processing rivid: 120340967
# Processing rivid: 120342195
# Processing rivid: 120342992
# Processing rivid: 120345713
# Processing rivid: 120346002
# Processing rivid: 120346574
# Processing rivid: 120350445
# Processing rivid: 120350487
# Processing rivid: 120352438
# Processing rivid: 120352646
# Processing rivid: 120353850
# Processing rivid: 120354237
# Processing rivid: 120354249
# Processing rivid: 120355529
# Processing rivid: 120355896
# Processing rivid: 120359220
# Processing rivid: 120359243
# Processing rivid: 120360942
# Processing rivid: 120361307
# Processing rivid: 120362614
# Processing rivid: 120365748
# Processing rivid: 120366478
# Processing rivid: 120369048
# Processing rivid: 120370889
# Processing rivid: 120372522
# Processing rivid: 120374234
# Processing rivid: 120374280
# Processing rivid: 120375715
# Processing rivid: 120375803
# Processing rivid: 120375846
# Processing rivid: 120376633
# Processing rivid: 120377077
# Processing rivid: 120377161
# Processing rivid: 120377330
# Processing rivid: 120377350
# Processing rivid: 120377537
# Processing rivid: 120377540
# Processing rivid: 120377976
# Processing rivid: 120382063
# Processing rivid: 120382334
# Processing rivid: 120382520
# Processing rivid: 120384039
# Processing rivid: 120384090
# Processing rivid: 120385725
# Processing rivid: 120385895
# Processing rivid: 120387414
# Processing rivid: 120387505
# Processing rivid: 120387982
# Processing rivid: 120390805
# Processing rivid: 120391782
# Processing rivid: 120394080
# Processing rivid: 120398981
# Processing rivid: 120399005
# Processing rivid: 120400800
# Processing rivid: 120402303
# Processing rivid: 120403963
# Processing rivid: 120403997
# Processing rivid: 120404012
# Processing rivid: 120404063
# Processing rivid: 120404102
# Processing rivid: 120404160
# Processing rivid: 120404236
# Processing rivid: 120407484
# Processing rivid: 120408707
# Processing rivid: 120410424
# Processing rivid: 120410585
# Processing rivid: 120410674
# Processing rivid: 120410740
# Processing rivid: 120412278
# Processing rivid: 120412359
# Processing rivid: 120412422
# Processing rivid: 120412457
# Processing rivid: 120412480
# Processing rivid: 120413957
# Processing rivid: 120415647
# Processing rivid: 120416245
# Processing rivid: 120417034
# Processing rivid: 120417313
# Processing rivid: 120418754
# Processing rivid: 120420053
# Processing rivid: 120420747
# Processing rivid: 120425394
# Processing rivid: 120425610
# Processing rivid: 120425703
# Processing rivid: 120428615
# Processing rivid: 120428693
# Processing rivid: 120429090
# Processing rivid: 120430579
# Processing rivid: 120432397
# Processing rivid: 120433978
# Processing rivid: 120437269
# Processing rivid: 120437901
# Processing rivid: 120438943
# Processing rivid: 120439031
# Processing rivid: 120440389
# Processing rivid: 120441551
# Processing rivid: 120441998
# Processing rivid: 120442060
# Processing rivid: 120442273
# Processing rivid: 120442277
# Processing rivid: 120442352
# Processing rivid: 120443868
# Processing rivid: 120443961
# Processing rivid: 120446649
# Processing rivid: 120447047
# Processing rivid: 120447247
# Processing rivid: 120447268
# Processing rivid: 120447889
# Processing rivid: 120447961
# Processing rivid: 120448919
# Processing rivid: 120448942
# Processing rivid: 120448944
# Processing rivid: 120449502
# Processing rivid: 120450001
# Processing rivid: 120450397
# Processing rivid: 120450600
# Processing rivid: 120451196
# Processing rivid: 120453618
# Processing rivid: 120453668
# Processing rivid: 120453717
# Processing rivid: 120453905
# Processing rivid: 120455041
# Processing rivid: 120455273
# Processing rivid: 120455392
# Processing rivid: 120457090
# Processing rivid: 120457231
# Processing rivid: 120458904
# Processing rivid: 120458959
# Processing rivid: 120459886
# Processing rivid: 120460478
# Processing rivid: 120460532
# Processing rivid: 120460597
# Processing rivid: 120460668
# Processing rivid: 120461952
# Processing rivid: 120462000
# Processing rivid: 120462252
# Processing rivid: 120463911
# Processing rivid: 120463929
# Processing rivid: 120463951
# Processing rivid: 120464506
# Processing rivid: 120464941
# Processing rivid: 120465287
# Processing rivid: 120465337
# Processing rivid: 120467167
# Processing rivid: 120467293
# Processing rivid: 120467296
# Processing rivid: 120468109
# Processing rivid: 120468290
# Processing rivid: 120468749
# Processing rivid: 120468968
# Processing rivid: 120470326
# Processing rivid: 120470515
# Processing rivid: 120470571
# Processing rivid: 120471947
# Processing rivid: 120472123
# Processing rivid: 120472139
# Processing rivid: 120473652
# Processing rivid: 120473868
# Processing rivid: 120473960
# Processing rivid: 120475323
# Processing rivid: 120475575
# Processing rivid: 120475626
# Processing rivid: 120477242
# Processing rivid: 120477855
# Processing rivid: 120478628
# Processing rivid: 120478650
# Processing rivid: 120478842
# Processing rivid: 120480282
# Processing rivid: 120480552
# Processing rivid: 120482183
# Processing rivid: 120482224
# Processing rivid: 120485278
# Processing rivid: 120486958
# Processing rivid: 120488620
# Processing rivid: 120488843
# Processing rivid: 120489535
# Processing rivid: 120490224
# Processing rivid: 120490250
# Processing rivid: 120491959
# Processing rivid: 120492174
# Processing rivid: 120492233
# Processing rivid: 120493287
# Processing rivid: 120493761
# Processing rivid: 120494609
# Processing rivid: 120495347
# Processing rivid: 120495360
# Processing rivid: 120495423
# Processing rivid: 120495491
# Processing rivid: 120497012
# Processing rivid: 120497140
# Processing rivid: 120498831
# Processing rivid: 120498901
# Processing rivid: 120500214
# Processing rivid: 120502045
# Processing rivid: 120502128
# Processing rivid: 120502224
# Processing rivid: 120505086
# Processing rivid: 120505462
# Processing rivid: 120506980
# Processing rivid: 120506983
# Processing rivid: 120507102
# Processing rivid: 120508041
# Processing rivid: 120510164
# Processing rivid: 120510254
# Processing rivid: 120511572
# Processing rivid: 120511579
# Processing rivid: 120511984
# Processing rivid: 120512219
# Processing rivid: 120513573
# Processing rivid: 120513622
# Processing rivid: 120513790
# Processing rivid: 120515338
# Processing rivid: 120515447
# Processing rivid: 120516117
# Processing rivid: 120516191
# Processing rivid: 120516444
# Processing rivid: 120516894
# Processing rivid: 120516979
# Processing rivid: 120516991
# Processing rivid: 120517081
# Processing rivid: 120518644
# Processing rivid: 120520227
# Processing rivid: 120520325
# Processing rivid: 120521236
# Processing rivid: 120521816
# Processing rivid: 120521841
# Processing rivid: 120522101
# Processing rivid: 120523570
# Processing rivid: 120523637
# Processing rivid: 120523679
# Processing rivid: 120523792
# Processing rivid: 120528636
# Processing rivid: 120528713
# Processing rivid: 120530209
# Processing rivid: 120530246
# Processing rivid: 120530440
# Processing rivid: 120531119
# Processing rivid: 120532011
# Processing rivid: 120533763
# Processing rivid: 120534477
# Processing rivid: 120535335
# Processing rivid: 120536082
# Processing rivid: 120536088
# Processing rivid: 120536092
# Processing rivid: 120536553
# Processing rivid: 120536977
# Processing rivid: 120537108
# Processing rivid: 120538047
# Processing rivid: 120538065
# Processing rivid: 120538615
# Processing rivid: 120538625
# Processing rivid: 120538632
# Processing rivid: 120538657
# Processing rivid: 120539486
# Processing rivid: 120539730
# Processing rivid: 120540201
# Processing rivid: 120540410
# Processing rivid: 120540411
# Processing rivid: 120541096
# Processing rivid: 120541824
# Processing rivid: 120541831
# Processing rivid: 120541856
# Processing rivid: 120541977
# Processing rivid: 120542798
# Processing rivid: 120543679
# Processing rivid: 120544574
# Processing rivid: 120545165
# Processing rivid: 120545200
# Processing rivid: 120545276
# Processing rivid: 120546089
# Processing rivid: 120546496
# Processing rivid: 120546505
# Processing rivid: 120546975
# Processing rivid: 120547058
# Processing rivid: 120548596
# Processing rivid: 120548603
# Processing rivid: 120548604
# Processing rivid: 120548707
# Processing rivid: 120549452
# Processing rivid: 120550203
# Processing rivid: 120550237
# Processing rivid: 120550261
# Processing rivid: 120550335
# Processing rivid: 120551838
# Processing rivid: 120552054
# Processing rivid: 120553028
# Processing rivid: 120553382
# Processing rivid: 120553543
# Processing rivid: 120556739
# Processing rivid: 120557714
# Processing rivid: 120558482
# Processing rivid: 120558534
# Processing rivid: 120558664
# Processing rivid: 120559802
# Processing rivid: 120560221
# Processing rivid: 120560357
# Processing rivid: 120561109
# Processing rivid: 120561453
# Processing rivid: 120561718
# Processing rivid: 120561795
# Processing rivid: 120561799
# Processing rivid: 120562713
# Processing rivid: 120563593
# Processing rivid: 120563675
# Processing rivid: 120564647
# Processing rivid: 120565325
# Processing rivid: 120566865
# Processing rivid: 120568542
# Processing rivid: 120568603
# Processing rivid: 120570053
# Processing rivid: 120570112
# Processing rivid: 120570224
# Processing rivid: 120570270
# Processing rivid: 120571028
# Processing rivid: 120571446
# Processing rivid: 120571789
# Processing rivid: 120571856
# Processing rivid: 120571869
# Processing rivid: 120572715
# Processing rivid: 120572851
# Processing rivid: 120572872
# Processing rivid: 120573666
# Processing rivid: 120576719
# Processing rivid: 120576827
# Processing rivid: 120577948
# Processing rivid: 120578510
# Processing rivid: 120578541
# Processing rivid: 120580065
# Processing rivid: 120583526
# Processing rivid: 120585290
# Processing rivid: 120588622
# Processing rivid: 120588646
# Processing rivid: 120590241
# Processing rivid: 120591793
# Processing rivid: 120593545
# Processing rivid: 120593602
# Processing rivid: 120596597
# Processing rivid: 120598433
# Processing rivid: 120600041
# Processing rivid: 120600097
# Processing rivid: 120600169
# Processing rivid: 120601916
# Processing rivid: 120603258
# Processing rivid: 120605156
# Processing rivid: 120605175
# Processing rivid: 120605224
# Processing rivid: 120606872
# Processing rivid: 120606874
# Processing rivid: 120607703
# Processing rivid: 120609454
# Processing rivid: 120609578
# Processing rivid: 120609608
# Processing rivid: 120609978
# Processing rivid: 120612738
# Processing rivid: 120612973
# Processing rivid: 120613551
# Processing rivid: 120615174
# Processing rivid: 120616128
# Processing rivid: 120616889
# Processing rivid: 120618396
# Processing rivid: 120620072
# Processing rivid: 120620995
# Processing rivid: 120621229
# Processing rivid: 120621684
# Processing rivid: 120621809
# Processing rivid: 120622787
# Processing rivid: 120623222
# Processing rivid: 120623242
# Processing rivid: 120623482
# Processing rivid: 120623567
# Processing rivid: 120626194
# Processing rivid: 120626364
# Processing rivid: 120626690
# Processing rivid: 120626810
# Processing rivid: 120628326
# Processing rivid: 120629935
# Processing rivid: 120630139
# Processing rivid: 120631112
# Processing rivid: 120631560
# Processing rivid: 120632867
# Processing rivid: 120633089
# Processing rivid: 120635997
# Processing rivid: 120636333
# Processing rivid: 120638042
# Processing rivid: 120638459
# Processing rivid: 120639286
# Processing rivid: 120639436
# Processing rivid: 120639732
# Processing rivid: 120640110
# Processing rivid: 120643088
# Processing rivid: 120643222
# Processing rivid: 120644418
# Processing rivid: 120645991
# Processing rivid: 120647679
# Processing rivid: 120648014
# Processing rivid: 120648262
# Processing rivid: 120648306
# Processing rivid: 120649651
# Processing rivid: 120651007
# Processing rivid: 120652936
# Processing rivid: 120654575
# Processing rivid: 120654920
# Processing rivid: 120655042
# Processing rivid: 120656487
# Processing rivid: 120656512
# Processing rivid: 120656656
# Processing rivid: 120657861
# Processing rivid: 120658177
# Processing rivid: 120661320
# Processing rivid: 120661372
# Processing rivid: 120668041
# Processing rivid: 120670978
# Processing rivid: 120671294
# Processing rivid: 120671579
# Processing rivid: 120672836
# Processing rivid: 120672891
# Processing rivid: 120673152
# Processing rivid: 120674635
# Processing rivid: 120674910
# Processing rivid: 120676024
# Processing rivid: 120679560
# Processing rivid: 120684660
# Processing rivid: 120687689
# Processing rivid: 120689657
# Processing rivid: 120691546
# Processing rivid: 120694484
# Processing rivid: 120696185
# Processing rivid: 120699856
# Processing rivid: 120706469
# Processing rivid: 120707837
# Processing rivid: 120711392
# Processing rivid: 120714549
# Processing rivid: 120719452
# Processing rivid: 120719778
# Processing rivid: 120721058
# Processing rivid: 120721131
# Processing rivid: 120722888
# Processing rivid: 120727730
# Processing rivid: 120731201
# Processing rivid: 120734461
# Processing rivid: 120736202
# Processing rivid: 120737888
# Processing rivid: 120739666
# Processing rivid: 120741330
# Processing rivid: 120742925
# Processing rivid: 120744552
# Processing rivid: 120746270
# Processing rivid: 120751120
# Processing rivid: 120754363
# Processing rivid: 120757864
# Processing rivid: 120767718
# Processing rivid: 120774405
# Processing rivid: 120781041
# Processing rivid: 120782668
# Processing rivid: 120834435
# Processing rivid: 120860885
# Processing rivid: 130094118
# Processing rivid: 130309490
# Processing rivid: 130314615
# Processing rivid: 130345427
# Processing rivid: 130395059
# Processing rivid: 130401890
# Processing rivid: 130403453
# Processing rivid: 130430928
# Processing rivid: 130460013
# Processing rivid: 130478845
# Processing rivid: 130492564
# Processing rivid: 130499375
# Processing rivid: 130521589
# Processing rivid: 130531931
# Processing rivid: 130547176
# Processing rivid: 130550692
# Processing rivid: 130550803
# Processing rivid: 130550818
# Processing rivid: 130566174
# Processing rivid: 130590162
# Processing rivid: 130613583
# Processing rivid: 130620945
# Processing rivid: 130624385
# Processing rivid: 130656869
# Processing rivid: 130674022
# Processing rivid: 130674794
# Processing rivid: 130705639
# Processing rivid: 130726194
# Processing rivid: 130727884
# Processing rivid: 130729692
# Processing rivid: 130769038
# Processing rivid: 130800352
# Processing rivid: 140257641
# Processing rivid: 140295477
# Processing rivid: 140295481
# Processing rivid: 140307112
# Processing rivid: 140343483
# Processing rivid: 140362427
# Processing rivid: 140372611
# Processing rivid: 140385705
# Processing rivid: 140388614
# Processing rivid: 140395878
# Processing rivid: 140429364
# Processing rivid: 140431694
# Processing rivid: 140432267
# Processing rivid: 140448965
# Processing rivid: 140472785
# Processing rivid: 140479603
# Processing rivid: 140484662
# Processing rivid: 140487530
# Processing rivid: 140490502
# Processing rivid: 140497717
# Processing rivid: 140504347
# Processing rivid: 140509431
# Processing rivid: 140515179
# Processing rivid: 140516710
# Processing rivid: 140519574
# Processing rivid: 140522535
# Processing rivid: 140523810
# Processing rivid: 140525412
# Processing rivid: 140529084
# Processing rivid: 140539979
# Processing rivid: 140542737
# Processing rivid: 140556730
# Processing rivid: 140560076
# Processing rivid: 140561171
# Processing rivid: 140568741
# Processing rivid: 140577833
# Processing rivid: 140578944
# Processing rivid: 140579289
# Processing rivid: 140580765
# Processing rivid: 140582140
# Processing rivid: 140582180
# Processing rivid: 140584781
# Processing rivid: 140585098
# Processing rivid: 140586561
# Processing rivid: 140587658
# Processing rivid: 140588003
# Processing rivid: 140590937
# Processing rivid: 140597846
# Processing rivid: 140601096
# Processing rivid: 140602575
# Processing rivid: 140606476
# Processing rivid: 140610883
# Processing rivid: 140610903
# Processing rivid: 140611309
# Processing rivid: 140619749
# Processing rivid: 140622448
# Processing rivid: 140623891
# Processing rivid: 140625620
# Processing rivid: 140632663
# Processing rivid: 140632696
# Processing rivid: 140632827
# Processing rivid: 140634553
# Processing rivid: 140637046
# Processing rivid: 140643177
# Processing rivid: 140643227
# Processing rivid: 140645914
# Processing rivid: 140646163
# Processing rivid: 140648690
# Processing rivid: 140650559
# Processing rivid: 140656126
# Processing rivid: 140657752
# Processing rivid: 140660169
# Processing rivid: 140665095
# Processing rivid: 140665132
# Processing rivid: 140669287
# Processing rivid: 140670948
# Processing rivid: 140673515
# Processing rivid: 140678212
# Processing rivid: 140679229
# Processing rivid: 140679597
# Processing rivid: 140679684
# Processing rivid: 140680647
# Processing rivid: 140680878
# Processing rivid: 140682436
# Processing rivid: 140683850
# Processing rivid: 140683870
# Processing rivid: 140686834
# Processing rivid: 140688398
# Processing rivid: 140691322
# Processing rivid: 140696998
# Processing rivid: 140697155
# Processing rivid: 140698525
# Processing rivid: 140699845
# Processing rivid: 140701291
# Processing rivid: 140704440
# Processing rivid: 140707200
# Processing rivid: 140710075
# Processing rivid: 140710290
# Processing rivid: 140711648
# Processing rivid: 140713022
# Processing rivid: 140715966
# Processing rivid: 140717041
# Processing rivid: 140718846
# Processing rivid: 140726127
# Processing rivid: 140726256
# Processing rivid: 140727707
# Processing rivid: 140736265
# Processing rivid: 140736294
# Processing rivid: 140739332
# Processing rivid: 140739361
# Processing rivid: 140746474
# Processing rivid: 140750918
# Processing rivid: 140752347
# Processing rivid: 140753769
# Processing rivid: 140766941
# Processing rivid: 150234194
# Processing rivid: 150250082
# Processing rivid: 150275877
# Processing rivid: 150293767
# Processing rivid: 150488274
# Processing rivid: 150526015
# Processing rivid: 150531926
# Processing rivid: 150539905
# Processing rivid: 150549957
# Processing rivid: 150559822
# Processing rivid: 150611484
# Processing rivid: 150700792
# Processing rivid: 150750399
# Processing rivid: 150845706
# Processing rivid: 160161112
# Processing rivid: 160200814
# Processing rivid: 160205470
# Processing rivid: 160217207
# Processing rivid: 160221792
# Processing rivid: 160233531
# Processing rivid: 160266239
# Processing rivid: 180147718
# Processing rivid: 180316531
# Processing rivid: 180343352
# Processing rivid: 180386515
# Processing rivid: 180399016
# Processing rivid: 180400008
# Processing rivid: 180406736
# Processing rivid: 180406743
# Processing rivid: 180409610
# Processing rivid: 180414349
# Processing rivid: 180417248
# Processing rivid: 210004017
# Processing rivid: 210005065
# Processing rivid: 210009311
# Processing rivid: 210010405
# Processing rivid: 210010565
# Processing rivid: 210011765
# Processing rivid: 210012501
# Processing rivid: 210012520
# Processing rivid: 210015691
# Processing rivid: 210016710
# Processing rivid: 210016903
# Processing rivid: 210016913
# Processing rivid: 210017749
# Processing rivid: 210020077
# Processing rivid: 210020930
# Processing rivid: 210021131
# Processing rivid: 210024299
# Processing rivid: 210025221
# Processing rivid: 210025363
# Processing rivid: 210026417
# Processing rivid: 210028540
# Processing rivid: 210028550
# Processing rivid: 210028685
# Processing rivid: 210029583
# Processing rivid: 210029588
# Processing rivid: 210029592
# Processing rivid: 210029593
# Processing rivid: 210029623
# Processing rivid: 210030644
# Processing rivid: 210030654
# Processing rivid: 210030656
# Processing rivid: 210031721
# Processing rivid: 210032784
# Processing rivid: 210032931
# Processing rivid: 210033816
# Processing rivid: 210033820
# Processing rivid: 210033822
# Processing rivid: 210033831
# Processing rivid: 210033839
# Processing rivid: 210033848
# Processing rivid: 210033987
# Processing rivid: 210034060
# Processing rivid: 210034867
# Processing rivid: 210034871
# Processing rivid: 210035940
# Processing rivid: 210035942
# Processing rivid: 210035943
# Processing rivid: 210035951
# Processing rivid: 210035952
# Processing rivid: 210035960
# Processing rivid: 210036978
# Processing rivid: 210036985
# Processing rivid: 210036987
# Processing rivid: 210037000
# Processing rivid: 210037011
# Processing rivid: 210038046
# Processing rivid: 210038058
# Processing rivid: 210039096
# Processing rivid: 210039098
# Processing rivid: 210039104
# Processing rivid: 210039119
# Processing rivid: 210039122
# Processing rivid: 210039125
# Processing rivid: 210039129
# Processing rivid: 210040156
# Processing rivid: 210040159
# Processing rivid: 210040175
# Processing rivid: 210040180
# Processing rivid: 210040205
# Processing rivid: 210041221
# Processing rivid: 210041231
# Processing rivid: 210041455
# Processing rivid: 210042279
# Processing rivid: 210042280
# Processing rivid: 210042282
# Processing rivid: 210042301
# Processing rivid: 210042458
# Processing rivid: 210043319
# Processing rivid: 210043322
# Processing rivid: 210043325
# Processing rivid: 210043341
# Processing rivid: 210043358
# Processing rivid: 210044386
# Processing rivid: 210044389
# Processing rivid: 210044394
# Processing rivid: 210044406
# Processing rivid: 210044415
# Processing rivid: 210045440
# Processing rivid: 210045444
# Processing rivid: 210045449
# Processing rivid: 210045450
# Processing rivid: 210045452
# Processing rivid: 210045458
# Processing rivid: 210045470
# Processing rivid: 210046494
# Processing rivid: 210046502
# Processing rivid: 210046505
# Processing rivid: 210046515
# Processing rivid: 210046519
# Processing rivid: 210047556
# Processing rivid: 210047566
# Processing rivid: 210047569
# Processing rivid: 210047585
# Processing rivid: 210047588
# Processing rivid: 210048612
# Processing rivid: 210048616
# Processing rivid: 210048627
# Processing rivid: 210048633
# Processing rivid: 210048641
# Processing rivid: 210049658
# Processing rivid: 210049661
# Processing rivid: 210049662
# Processing rivid: 210049665
# Processing rivid: 210049666
# Processing rivid: 210049667
# Processing rivid: 210049673
# Processing rivid: 210049679
# Processing rivid: 210049689
# Processing rivid: 210049694
# Processing rivid: 210050730
# Processing rivid: 210050731
# Processing rivid: 210050736
# Processing rivid: 210051773
# Processing rivid: 210051779
# Processing rivid: 210051790
# Processing rivid: 210052835
# Processing rivid: 210052838
# Processing rivid: 210052846
# Processing rivid: 210052866
# Processing rivid: 210053891
# Processing rivid: 210053892
# Processing rivid: 210053901
# Processing rivid: 210053926
# Processing rivid: 210054954
# Processing rivid: 210054958
# Processing rivid: 210054973
# Processing rivid: 210054984
# Processing rivid: 210054989
# Processing rivid: 210056015
# Processing rivid: 210057059
# Processing rivid: 210057066
# Processing rivid: 210057073
# Processing rivid: 210057078
# Processing rivid: 210058113
# Processing rivid: 210058133
# Processing rivid: 210058155
# Processing rivid: 210058177
# Processing rivid: 210059189
# Processing rivid: 210060262
# Processing rivid: 210060263
# Processing rivid: 210061283
# Processing rivid: 210061302
# Processing rivid: 210061316
# Processing rivid: 210062340
# Processing rivid: 210062373
# Processing rivid: 210063393
# Processing rivid: 210063396
# Processing rivid: 210063410
# Processing rivid: 210063414
# Processing rivid: 210063422
# Processing rivid: 210063438
# Processing rivid: 210063442
# Processing rivid: 210064470
# Processing rivid: 210064502
# Processing rivid: 210065525
# Processing rivid: 210065545
# Processing rivid: 210066598
# Processing rivid: 210066616
# Processing rivid: 210067648
# Processing rivid: 210067654
# Processing rivid: 210068704
# Processing rivid: 210069760
# Processing rivid: 210072940
# Processing rivid: 210073987
# Processing rivid: 210074001
# Processing rivid: 210075040
# Processing rivid: 210075049
# Processing rivid: 210077155
# Processing rivid: 210080335
# Processing rivid: 210080338
# Processing rivid: 210084563
# Processing rivid: 210085610
# Processing rivid: 210085614
# Processing rivid: 210086678
# Processing rivid: 210087733
# Processing rivid: 210090040
# Processing rivid: 210090894
# Processing rivid: 210096194
# Processing rivid: 210096370
# Processing rivid: 210097240
# Processing rivid: 210099534
# Processing rivid: 210100545
# Processing rivid: 210102613
# Processing rivid: 210104697
# Processing rivid: 210105879
# Processing rivid: 210108855
# Processing rivid: 210108868
# Processing rivid: 210108942
# Processing rivid: 210109920
# Processing rivid: 210109967
# Processing rivid: 210110980
# Processing rivid: 210113081
# Processing rivid: 210115319
# Processing rivid: 210116313
# Processing rivid: 210116337
# Processing rivid: 210117303
# Processing rivid: 210117323
# Processing rivid: 210118472
# Processing rivid: 210119545
# Processing rivid: 210120576
# Processing rivid: 210120605
# Processing rivid: 210121652
# Processing rivid: 210122587
# Processing rivid: 210122689
# Processing rivid: 210122711
# Processing rivid: 210122712
# Processing rivid: 210123640
# Processing rivid: 210123687
# Processing rivid: 210123712
# Processing rivid: 210123744
# Processing rivid: 210123755
# Processing rivid: 210123764
# Processing rivid: 210123780
# Processing rivid: 210123822
# Processing rivid: 210124811
# Processing rivid: 210124876
# Processing rivid: 210125753
# Processing rivid: 210127937
# Processing rivid: 210127992
# Processing rivid: 210129089
# Processing rivid: 210131082
# Processing rivid: 210131113
# Processing rivid: 210131127
# Processing rivid: 210131129
# Processing rivid: 210131162
# Processing rivid: 210131236
# Processing rivid: 210132151
# Processing rivid: 210132228
# Processing rivid: 210132275
# Processing rivid: 210132276
# Processing rivid: 210133222
# Processing rivid: 210133271
# Processing rivid: 210133337
# Processing rivid: 210134220
# Processing rivid: 210134229
# Processing rivid: 210134262
# Processing rivid: 210134291
# Processing rivid: 210135311
# Processing rivid: 210135347
# Processing rivid: 210135424
# Processing rivid: 210135448
# Processing rivid: 210136314
# Processing rivid: 210136318
# Processing rivid: 210136439
# Processing rivid: 210137409
# Processing rivid: 210137437
# Processing rivid: 210137448
# Processing rivid: 210137469
# Processing rivid: 210137508
# Processing rivid: 210137526
# Processing rivid: 210138445
# Processing rivid: 210138528
# Processing rivid: 210138540
# Processing rivid: 210138544
# Processing rivid: 210138547
# Processing rivid: 210138551
# Processing rivid: 210138553
# Processing rivid: 210139554
# Processing rivid: 210139571
# Processing rivid: 210139601
# Processing rivid: 210139608
# Processing rivid: 210139610
# Processing rivid: 210139639
# Processing rivid: 210139643
# Processing rivid: 210140606
# Processing rivid: 210140610
# Processing rivid: 210141603
# Processing rivid: 210141653
# Processing rivid: 210141681
# Processing rivid: 210141684
# Processing rivid: 210141780
# Processing rivid: 210142709
# Processing rivid: 210142710
# Processing rivid: 210142824
# Processing rivid: 210142832
# Processing rivid: 210142848
# Processing rivid: 210143706
# Processing rivid: 210143859
# Processing rivid: 210143873
# Processing rivid: 210143878
# Processing rivid: 210144856
# Processing rivid: 210144934
# Processing rivid: 210144940
# Processing rivid: 210145818
# Processing rivid: 210145830
# Processing rivid: 210145834
# Processing rivid: 210145837
# Processing rivid: 210145856
# Processing rivid: 210145920
# Processing rivid: 210145939
# Processing rivid: 210145997
# Processing rivid: 210146874
# Processing rivid: 210147015
# Processing rivid: 210148009
# Processing rivid: 210148026
# Processing rivid: 210148036
# Processing rivid: 210148068
# Processing rivid: 210149088
# Processing rivid: 210150097
# Processing rivid: 210150142
# Processing rivid: 210150164
# Processing rivid: 210150193
# Processing rivid: 210150222
# Processing rivid: 210150233
# Processing rivid: 210151106
# Processing rivid: 210151195
# Processing rivid: 210151200
# Processing rivid: 210152158
# Processing rivid: 210152202
# Processing rivid: 210152207
# Processing rivid: 210152226
# Processing rivid: 210152279
# Processing rivid: 210152292
# Processing rivid: 210152303
# Processing rivid: 210152326
# Processing rivid: 210152332
# Processing rivid: 210152337
# Processing rivid: 210153396
# Processing rivid: 210154284
# Processing rivid: 210154401
# Processing rivid: 210154429
# Processing rivid: 210154452
# Processing rivid: 210155330
# Processing rivid: 210155345
# Processing rivid: 210155361
# Processing rivid: 210155400
# Processing rivid: 210155416
# Processing rivid: 210155457
# Processing rivid: 210155474
# Processing rivid: 210155501
# Processing rivid: 210156519
# Processing rivid: 210157447
# Processing rivid: 210157492
# Processing rivid: 210157501
# Processing rivid: 210157520
# Processing rivid: 210157576
# Processing rivid: 210158544
# Processing rivid: 210158554
# Processing rivid: 210158576
# Processing rivid: 210158591
# Processing rivid: 210158601
# Processing rivid: 210158648
# Processing rivid: 210158657
# Processing rivid: 210159565
# Processing rivid: 210159570
# Processing rivid: 210159575
# Processing rivid: 210159665
# Processing rivid: 210159685
# Processing rivid: 210159714
# Processing rivid: 210159726
# Processing rivid: 210159728
# Processing rivid: 210160608
# Processing rivid: 210160635
# Processing rivid: 210160781
# Processing rivid: 210160784
# Processing rivid: 210161662
# Processing rivid: 210161680
# Processing rivid: 210161713
# Processing rivid: 210161723
# Processing rivid: 210161731
# Processing rivid: 210161772
# Processing rivid: 210161798
# Processing rivid: 210161816
# Processing rivid: 210161832
# Processing rivid: 210163812
# Processing rivid: 210163832
# Processing rivid: 210163873
# Processing rivid: 210163927
# Processing rivid: 210163944
# Processing rivid: 210163948
# Processing rivid: 210164960
# Processing rivid: 210164963
# Processing rivid: 210164979
# Processing rivid: 210164987
# Processing rivid: 210165000
# Processing rivid: 210165938
# Processing rivid: 210165981
# Processing rivid: 210166043
# Processing rivid: 210166944
# Processing rivid: 210167002
# Processing rivid: 210167060
# Processing rivid: 210167090
# Processing rivid: 210167094
# Processing rivid: 210167116
# Processing rivid: 210167142
# Processing rivid: 210168007
# Processing rivid: 210168017
# Processing rivid: 210168043
# Processing rivid: 210168054
# Processing rivid: 210168072
# Processing rivid: 210168090
# Processing rivid: 210168161
# Processing rivid: 210168165
# Processing rivid: 210168198
# Processing rivid: 210169083
# Processing rivid: 210169178
# Processing rivid: 210169201
# Processing rivid: 210169232
# Processing rivid: 210170115
# Processing rivid: 210170162
# Processing rivid: 210170180
# Processing rivid: 210170208
# Processing rivid: 210170238
# Processing rivid: 210171174
# Processing rivid: 210171180
# Processing rivid: 210171218
# Processing rivid: 210171272
# Processing rivid: 210171293
# Processing rivid: 210171301
# Processing rivid: 210171306
# Processing rivid: 210171346
# Processing rivid: 210172245
# Processing rivid: 210172272
# Processing rivid: 210172306
# Processing rivid: 210172351
# Processing rivid: 210172355
# Processing rivid: 210173387
# Processing rivid: 210173424
# Processing rivid: 210173426
# Processing rivid: 210174368
# Processing rivid: 210174398
# Processing rivid: 210174437
# Processing rivid: 210174484
# Processing rivid: 210174509
# Processing rivid: 210174522
# Processing rivid: 210174527
# Processing rivid: 210175445
# Processing rivid: 210175499
# Processing rivid: 210176467
# Processing rivid: 210176537
# Processing rivid: 210176585
# Processing rivid: 210176617
# Processing rivid: 210176634
# Processing rivid: 210177521
# Processing rivid: 210177563
# Processing rivid: 210177566
# Processing rivid: 210177570
# Processing rivid: 210177600
# Processing rivid: 210177631
# Processing rivid: 210177662
# Processing rivid: 210177674
# Processing rivid: 210177681
# Processing rivid: 210178648
# Processing rivid: 210178738
# Processing rivid: 210179645
# Processing rivid: 210179663
# Processing rivid: 210179670
# Processing rivid: 210179783
# Processing rivid: 210180686
# Processing rivid: 210180795
# Processing rivid: 210180802
# Processing rivid: 210180807
# Processing rivid: 210180841
# Processing rivid: 210181764
# Processing rivid: 210181890
# Processing rivid: 210181906
# Processing rivid: 210182846
# Processing rivid: 210182848
# Processing rivid: 210182873
# Processing rivid: 210182877
# Processing rivid: 210182908
# Processing rivid: 210182910
# Processing rivid: 210182945
# Processing rivid: 210183840
# Processing rivid: 210183974
# Processing rivid: 210183987
# Processing rivid: 210183992
# Processing rivid: 210183995
# Processing rivid: 210184034
# Processing rivid: 210184036
# Processing rivid: 210184903
# Processing rivid: 210184912
# Processing rivid: 210184913
# Processing rivid: 210184914
# Processing rivid: 210184959
# Processing rivid: 210184981
# Processing rivid: 210184985
# Processing rivid: 210185024
# Processing rivid: 210185025
# Processing rivid: 210185049
# Processing rivid: 210185062
# Processing rivid: 210185071
# Processing rivid: 210185094
# Processing rivid: 210185960
# Processing rivid: 210185963
# Processing rivid: 210185978
# Processing rivid: 210185981
# Processing rivid: 210185984
# Processing rivid: 210186022
# Processing rivid: 210186045
# Processing rivid: 210186049
# Processing rivid: 210186075
# Processing rivid: 210186076
# Processing rivid: 210186078
# Processing rivid: 210186091
# Processing rivid: 210186093
# Processing rivid: 210186102
# Processing rivid: 210186122
# Processing rivid: 210186138
# Processing rivid: 210187019
# Processing rivid: 210187101
# Processing rivid: 210187120
# Processing rivid: 210187129
# Processing rivid: 210187138
# Processing rivid: 210187153
# Processing rivid: 210188088
# Processing rivid: 210188090
# Processing rivid: 210188103
# Processing rivid: 210188150
# Processing rivid: 210188170
# Processing rivid: 210188237
# Processing rivid: 210188240
# Processing rivid: 210189162
# Processing rivid: 210189174
# Processing rivid: 210189189
# Processing rivid: 210189261
# Processing rivid: 210189264
# Processing rivid: 210189285
# Processing rivid: 210190191
# Processing rivid: 210190243
# Processing rivid: 210190252
# Processing rivid: 210190258
# Processing rivid: 210190331
# Processing rivid: 210190347
# Processing rivid: 210190365
# Processing rivid: 210191271
# Processing rivid: 210191314
# Processing rivid: 210191329
# Processing rivid: 210191352
# Processing rivid: 210191353
# Processing rivid: 210191356
# Processing rivid: 210191390
# Processing rivid: 210191433
# Processing rivid: 210192292
# Processing rivid: 210192314
# Processing rivid: 210192417
# Processing rivid: 210192434
# Processing rivid: 210192440
# Processing rivid: 210192445
# Processing rivid: 210192449
# Processing rivid: 210193393
# Processing rivid: 210193443
# Processing rivid: 210193473
# Processing rivid: 210193494
# Processing rivid: 210193520
# Processing rivid: 210194406
# Processing rivid: 210194434
# Processing rivid: 210194467
# Processing rivid: 210194480
# Processing rivid: 210194515
# Processing rivid: 210194517
# Processing rivid: 210194520
# Processing rivid: 210194555
# Processing rivid: 210194569
# Processing rivid: 210195466
# Processing rivid: 210195566
# Processing rivid: 210195573
# Processing rivid: 210195576
# Processing rivid: 210195588
# Processing rivid: 210195604
# Processing rivid: 210195623
# Processing rivid: 210195646
# Processing rivid: 210196529
# Processing rivid: 210196541
# Processing rivid: 210196604
# Processing rivid: 210196626
# Processing rivid: 210196670
# Processing rivid: 210197582
# Processing rivid: 210197613
# Processing rivid: 210197701
# Processing rivid: 210197760
# Processing rivid: 210198631
# Processing rivid: 210198640
# Processing rivid: 210198677
# Processing rivid: 210198752
# Processing rivid: 210198782
# Processing rivid: 210199686
# Processing rivid: 210199694
# Processing rivid: 210199726
# Processing rivid: 210199756
# Processing rivid: 210199791
# Processing rivid: 210199798
# Processing rivid: 210199808
# Processing rivid: 210199881
# Processing rivid: 210200745
# Processing rivid: 210200762
# Processing rivid: 210200772
# Processing rivid: 210200783
# Processing rivid: 210200865
# Processing rivid: 210200883
# Processing rivid: 210200935
# Processing rivid: 210201818
# Processing rivid: 210201866
# Processing rivid: 210201867
# Processing rivid: 210201871
# Processing rivid: 210201911
# Processing rivid: 210201989
# Processing rivid: 210202863
# Processing rivid: 210202887
# Processing rivid: 210202951
# Processing rivid: 210202984
# Processing rivid: 210203000
# Processing rivid: 210203002
# Processing rivid: 210203932
# Processing rivid: 210203934
# Processing rivid: 210203987
# Processing rivid: 210204014
# Processing rivid: 210204064
# Processing rivid: 210205036
# Processing rivid: 210205070
# Processing rivid: 210205111
# Processing rivid: 210206047
# Processing rivid: 210206062
# Processing rivid: 210206108
# Processing rivid: 210206135
# Processing rivid: 210206157
# Processing rivid: 210206174
# Processing rivid: 210206215
# Processing rivid: 210207088
# Processing rivid: 210207095
# Processing rivid: 210207116
# Processing rivid: 210207119
# Processing rivid: 210207122
# Processing rivid: 210207126
# Processing rivid: 210207176
# Processing rivid: 210207194
# Processing rivid: 210207200
# Processing rivid: 210207233
# Processing rivid: 210207242
# Processing rivid: 210207272
# Processing rivid: 210208134
# Processing rivid: 210208142
# Processing rivid: 210208188
# Processing rivid: 210208210
# Processing rivid: 210208277
# Processing rivid: 210208289
# Processing rivid: 210208297
# Processing rivid: 210208298
# Processing rivid: 210208318
# Processing rivid: 210209332
# Processing rivid: 210209348
# Processing rivid: 210210328
# Processing rivid: 210210392
# Processing rivid: 210211336
# Processing rivid: 210211371
# Processing rivid: 210211379
# Processing rivid: 210211439
# Processing rivid: 210211444
# Processing rivid: 210211449
# Processing rivid: 210211488
# Processing rivid: 210212505
# Processing rivid: 210212509
# Processing rivid: 210213423
# Processing rivid: 210213458
# Processing rivid: 210213471
# Processing rivid: 210213543
# Processing rivid: 210213545
# Processing rivid: 210213547
# Processing rivid: 210213555
# Processing rivid: 210213572
# Processing rivid: 210213596
# Processing rivid: 210213605
# Processing rivid: 210214470
# Processing rivid: 210214491
# Processing rivid: 210214504
# Processing rivid: 210214522
# Processing rivid: 210214617
# Processing rivid: 210214618
# Processing rivid: 210214619
# Processing rivid: 210214639
# Processing rivid: 210215525
# Processing rivid: 210215532
# Processing rivid: 210215679
# Processing rivid: 210215708
# Processing rivid: 210216685
# Processing rivid: 210216706
# Processing rivid: 210216739
# Processing rivid: 210216740
# Processing rivid: 210217743
# Processing rivid: 210217769
# Processing rivid: 210218709
# Processing rivid: 210218712
# Processing rivid: 210218736
# Processing rivid: 210218746
# Processing rivid: 210220863
# Processing rivid: 210220936
# Processing rivid: 210220964
# Processing rivid: 210220975
# Processing rivid: 210221968
# Processing rivid: 210221986
# Processing rivid: 210221995
# Processing rivid: 210221996
# Processing rivid: 210221998
# Processing rivid: 210222002
# Processing rivid: 210222955
# Processing rivid: 210223051
# Processing rivid: 210223079
# Processing rivid: 210223180
# Processing rivid: 210223995
# Processing rivid: 210224022
# Processing rivid: 210224035
# Processing rivid: 210224110
# Processing rivid: 210225071
# Processing rivid: 210225073
# Processing rivid: 210225155
# Processing rivid: 210225165
# Processing rivid: 210226159
# Processing rivid: 210226183
# Processing rivid: 210226208
# Processing rivid: 210226296
# Processing rivid: 210227166
# Processing rivid: 210227182
# Processing rivid: 210227208
# Processing rivid: 210227238
# Processing rivid: 210227247
# Processing rivid: 210227306
# Processing rivid: 210228264
# Processing rivid: 210228340
# Processing rivid: 210228355
# Processing rivid: 210229254
# Processing rivid: 210229351
# Processing rivid: 210230320
# Processing rivid: 210231365
# Processing rivid: 210231435
# Processing rivid: 210231495
# Processing rivid: 210231500
# Processing rivid: 210231502
# Processing rivid: 210231507
# Processing rivid: 210231514
# Processing rivid: 210231556
# Processing rivid: 210232436
# Processing rivid: 210232556
# Processing rivid: 210232572
# Processing rivid: 210232680
# Processing rivid: 210233491
# Processing rivid: 210233581
# Processing rivid: 210233607
# Processing rivid: 210233610
# Processing rivid: 210234637
# Processing rivid: 210234650
# Processing rivid: 210234656
# Processing rivid: 210234665
# Processing rivid: 210235611
# Processing rivid: 210235616
# Processing rivid: 210235623
# Processing rivid: 210235693
# Processing rivid: 210235720
# Processing rivid: 210235721
# Processing rivid: 210235722
# Processing rivid: 210235732
# Processing rivid: 210235741
# Processing rivid: 210235805
# Processing rivid: 210236669
# Processing rivid: 210236675
# Processing rivid: 210236722
# Processing rivid: 210236800
# Processing rivid: 210236850
# Processing rivid: 210237735
# Processing rivid: 210237803
# Processing rivid: 210237848
# Processing rivid: 210238859
# Processing rivid: 210238890
# Processing rivid: 210238905
# Processing rivid: 210238951
# Processing rivid: 210239822
# Processing rivid: 210239840
# Processing rivid: 210240946
# Processing rivid: 210240992
# Processing rivid: 210241076
# Processing rivid: 210241078
# Processing rivid: 210243058
# Processing rivid: 210244139
# Processing rivid: 210244172
# Processing rivid: 210244180
# Processing rivid: 210245225
# Processing rivid: 210245247
# Processing rivid: 210245489
# Processing rivid: 210246289
# Processing rivid: 210246296
# Processing rivid: 210247235
# Processing rivid: 210247342
# Processing rivid: 210248405
# Processing rivid: 210248419
# Processing rivid: 210249449
# Processing rivid: 210250580
# Processing rivid: 210251561
# Processing rivid: 210251626
# Processing rivid: 210252738
# Processing rivid: 210254853
# Processing rivid: 210255810
# Processing rivid: 210255993
# Processing rivid: 210257102
# Processing rivid: 210257902
# Processing rivid: 210259215
# Processing rivid: 210260084
# Processing rivid: 210260319
# Processing rivid: 210260959
# Processing rivid: 210261065
# Processing rivid: 210261135
# Processing rivid: 210262121
# Processing rivid: 210262196
# Processing rivid: 210263177
# Processing rivid: 210264546
# Processing rivid: 210265360
# Processing rivid: 210266417
# Processing rivid: 210266419
# Processing rivid: 210266538
# Processing rivid: 210267401
# Processing rivid: 210267493
# Processing rivid: 210269520
# Processing rivid: 210271829
# Processing rivid: 210272745
# Processing rivid: 210274818
# Processing rivid: 210275009
# Processing rivid: 210278895
# Processing rivid: 210279081
# Processing rivid: 210279099
# Processing rivid: 210279951
# Processing rivid: 210280137
# Processing rivid: 210280152
# Processing rivid: 210280202
# Processing rivid: 210281245
# Processing rivid: 210281257
# Processing rivid: 210282192
# Processing rivid: 210282252
# Processing rivid: 210287708
# Processing rivid: 210288619
# Processing rivid: 210291763
# Processing rivid: 210291767
# Processing rivid: 210293887
# Processing rivid: 210293916
# Processing rivid: 210294922
# Processing rivid: 210295978
# Processing rivid: 210297291
# Processing rivid: 210301272
# Processing rivid: 210302318
# Processing rivid: 210302343
# Processing rivid: 210305491
# Processing rivid: 210305542
# Processing rivid: 210305615
# Processing rivid: 210306555
# Processing rivid: 210310879
# Processing rivid: 210315029
# Processing rivid: 210319234
# Processing rivid: 210319326
# Processing rivid: 210320322
# Processing rivid: 210321346
# Processing rivid: 210322388
# Processing rivid: 210322396
# Processing rivid: 210330839
# Processing rivid: 210334052
# Processing rivid: 210335097
# Processing rivid: 210337181
# Processing rivid: 210338223
# Processing rivid: 210340337
# Processing rivid: 210340355
# Processing rivid: 210343500
# Processing rivid: 210343511
# Processing rivid: 210349837
# Processing rivid: 210350900
# Processing rivid: 210350904
# Processing rivid: 210350908
# Processing rivid: 210350918
# Processing rivid: 210351960
# Processing rivid: 210357312
# Processing rivid: 210360398
# Processing rivid: 210360403
# Processing rivid: 210360412
# Processing rivid: 210360419
# ...
# Processing rivid: 770323740
# Processing rivid: 770323750
# Processing rivid: 770325293
# Processing rivid: 770327288
# Processing rivid: 770328043
# Processing rivid: 770329107
# Processing rivid: 770329858
# Processing rivid: 770330008
# Processing rivid: 770330381
# Processing rivid: 770333224
# Processing rivid: 770333270
# Processing rivid: 770333272
# Processing rivid: 770335293
# Processing rivid: 770335578
# Processing rivid: 770335611
# Processing rivid: 770336208
# Processing rivid: 770336349
# Processing rivid: 770336656
# Processing rivid: 770337389
# Processing rivid: 770337406
# Processing rivid: 770337690
# Processing rivid: 770338442
# Processing rivid: 770338458
# Processing rivid: 770338472
# Processing rivid: 770340386
# Processing rivid: 770342496
# Processing rivid: 770342608
# Processing rivid: 770344547
# Processing rivid: 770345459
# Processing rivid: 770345726
# Processing rivid: 770345988
# Processing rivid: 770347028
# Processing rivid: 770347538
# Processing rivid: 770347814
# Processing rivid: 770350148
# Processing rivid: 770351788
# Processing rivid: 770354329
# Processing rivid: 770354832
# Processing rivid: 770355079
# Processing rivid: 770355345
# Processing rivid: 770355362
# Processing rivid: 770355370
# Processing rivid: 770357153
# Processing rivid: 770358052
# Processing rivid: 770359504
# Processing rivid: 770359507
# Processing rivid: 770359519
# Processing rivid: 770360557
# Processing rivid: 770362101
# Processing rivid: 770363361
# Processing rivid: 770364450
# Processing rivid: 770364706
# Processing rivid: 770365743
# Processing rivid: 770366783
# Processing rivid: 770367312
# Processing rivid: 770367315
# Processing rivid: 770367559
# Processing rivid: 770367584
# Processing rivid: 770367825
# Processing rivid: 770368608
# Processing rivid: 770368871
# Processing rivid: 770368884
# Processing rivid: 770368889
# Processing rivid: 770369486
# Processing rivid: 770369905
# Processing rivid: 770369909
# Processing rivid: 770369917
# Processing rivid: 770369929
# Processing rivid: 770370502
# Processing rivid: 770371560
# Processing rivid: 770371695
# Processing rivid: 770371997
# Processing rivid: 770373044
# Processing rivid: 770373791
# Processing rivid: 770374591
# Processing rivid: 770377689
# Processing rivid: 770377865
# Processing rivid: 770378730
# Processing rivid: 770378870
# Processing rivid: 770381861
# Processing rivid: 770383941
# Processing rivid: 770384113
# Processing rivid: 770384164
# Processing rivid: 770384462
# Processing rivid: 770386274
# Processing rivid: 770387080
# Processing rivid: 770387594
# Processing rivid: 770388218
# Processing rivid: 770389135
# Processing rivid: 770389337
# Processing rivid: 770389353
# Processing rivid: 770389395
# Processing rivid: 770390179
# Processing rivid: 770391411
# Processing rivid: 770391429
# Processing rivid: 770392402
# Processing rivid: 770392433
# Processing rivid: 770392441
# Processing rivid: 770394350
# Processing rivid: 770394354
# Processing rivid: 770394596
# Processing rivid: 770396419
# Processing rivid: 770396439
# Processing rivid: 770397461
# Processing rivid: 770397475
# Processing rivid: 770398756
# Processing rivid: 770399564
# Processing rivid: 770399701
# Processing rivid: 770400742
# Processing rivid: 770401615
# Processing rivid: 770402664
# Processing rivid: 770402826
# Processing rivid: 770403892
# Processing rivid: 770403904
# Processing rivid: 770404869
# Processing rivid: 770404996
# Processing rivid: 770405274
# Processing rivid: 770405916
# Processing rivid: 770406935
# Processing rivid: 770406962
# Processing rivid: 770409031
# Processing rivid: 770409434
# Processing rivid: 770410105
# Processing rivid: 770410975
# Processing rivid: 770411087
# Processing rivid: 770411146
# Processing rivid: 770411511
# Processing rivid: 770412025
# Processing rivid: 770414102
# Processing rivid: 770414271
# Processing rivid: 770415152
# Processing rivid: 770415247
# Processing rivid: 770416188
# Processing rivid: 770416279
# Processing rivid: 770417216
# Processing rivid: 770417229
# Processing rivid: 770418259
# Processing rivid: 770419304
# Processing rivid: 770419457
# Processing rivid: 770419465
# Processing rivid: 770420461
# Processing rivid: 770420465
# Processing rivid: 770421385
# Processing rivid: 770422424
# Processing rivid: 770422541
# Processing rivid: 770422619
# Processing rivid: 770423625
# Processing rivid: 770425539
# Processing rivid: 770425708
# Processing rivid: 770426595
# Processing rivid: 770426703
# Processing rivid: 770428659
# Processing rivid: 770429819
# Processing rivid: 770429827
# Processing rivid: 770431857
# Processing rivid: 770431904
# Processing rivid: 770431967
# Processing rivid: 770432825
# Processing rivid: 770433010
# Processing rivid: 770434020
# Processing rivid: 770435030
# Processing rivid: 770435953
# Processing rivid: 770436048
# Processing rivid: 770436064
# Processing rivid: 770436976
# Processing rivid: 770437167
# Processing rivid: 770438027
# Processing rivid: 770439232
# Processing rivid: 770440281
# Processing rivid: 770441246
# Processing rivid: 770441274
# Processing rivid: 770441290
# Processing rivid: 770442202
# Processing rivid: 770443238
# Processing rivid: 770443377
# Processing rivid: 770444388
# Processing rivid: 770444390
# Processing rivid: 770445308
# Processing rivid: 770445416
# Processing rivid: 770445431
# Processing rivid: 770447480
# Processing rivid: 770447532
# Processing rivid: 770448570
# Processing rivid: 770449509
# Processing rivid: 770451672
# Processing rivid: 770452701
# Processing rivid: 770453784
# Processing rivid: 770454669
# Processing rivid: 770455749
# Processing rivid: 770455817
# Processing rivid: 770456751
# Processing rivid: 770456889
# Processing rivid: 770456904
# Processing rivid: 770457911
# Processing rivid: 770457916
# Processing rivid: 770458951
# Processing rivid: 770459876
# Processing rivid: 770460027
# Processing rivid: 770460044
# Processing rivid: 770460897
# Processing rivid: 770460934
# Processing rivid: 770461047
# Processing rivid: 770461079
# Processing rivid: 770461950
# Processing rivid: 770462091
# Processing rivid: 770463096
# Processing rivid: 770464017
# Processing rivid: 770465218
# Processing rivid: 770466109
# Processing rivid: 770467289
# Processing rivid: 770468204
# Processing rivid: 770469238
# Processing rivid: 770469241
# Processing rivid: 770470275
# Processing rivid: 770470388
# Processing rivid: 770470393
# Processing rivid: 770471422
# Processing rivid: 770471432
# Processing rivid: 770471436
# Processing rivid: 770472449
# Processing rivid: 770473401
# Processing rivid: 770473501
# Processing rivid: 770474550
# Processing rivid: 770474551
# Processing rivid: 770475460
# Processing rivid: 770477556
# Processing rivid: 770478604
# Processing rivid: 770478712
# Processing rivid: 770480721
# Processing rivid: 770481719
# Processing rivid: 770481764
# Processing rivid: 770481804
# Processing rivid: 770481838
# Processing rivid: 770482854
# Processing rivid: 770483794
# Processing rivid: 770483822
# Processing rivid: 770484955
# Processing rivid: 770485877
# Processing rivid: 770485879
# Processing rivid: 770486917
# Processing rivid: 770487002
# Processing rivid: 770487024
# Processing rivid: 770488039
# Processing rivid: 770488081
# Processing rivid: 770489100
# Processing rivid: 770490042
# Processing rivid: 770490060
# Processing rivid: 770490158
# Processing rivid: 770492121
# Processing rivid: 770492229
# Processing rivid: 770492236
# Processing rivid: 770493173
# Processing rivid: 770493293
# Processing rivid: 770495243
# Processing rivid: 770495277
# Processing rivid: 770495363
# Processing rivid: 770496410
# Processing rivid: 770497455
# Processing rivid: 770498377
# Processing rivid: 770498473
# Processing rivid: 770499404
# Processing rivid: 770499496
# Processing rivid: 770500455
# Processing rivid: 770502640
# Processing rivid: 770502643
# Processing rivid: 770503560
# Processing rivid: 770504694
# Processing rivid: 770505639
# Processing rivid: 770505693
# Processing rivid: 770505737
# Processing rivid: 770505743
# Processing rivid: 770506697
# Processing rivid: 770508756
# Processing rivid: 770508788
# Processing rivid: 770508789
# Processing rivid: 770509797
# Processing rivid: 770509820
# Processing rivid: 770509915
# Processing rivid: 770510841
# Processing rivid: 770510892
# Processing rivid: 770510951
# Processing rivid: 770511974
# Processing rivid: 770512926
# Processing rivid: 770513979
# Processing rivid: 770514043
# Processing rivid: 770515025
# Processing rivid: 770515070
# Processing rivid: 770515093
# Processing rivid: 770516081
# Processing rivid: 770517081
# Processing rivid: 770517204
# Processing rivid: 770518147
# Processing rivid: 770518216
# Processing rivid: 770519231
# Processing rivid: 770519249
# Processing rivid: 770520229
# Processing rivid: 770520302
# Processing rivid: 770521282
# Processing rivid: 770521329
# Processing rivid: 770523422
# Processing rivid: 770524357
# Processing rivid: 770524363
# Processing rivid: 770524431
# Processing rivid: 770525407
# Processing rivid: 770525471
# Processing rivid: 770525485
# Processing rivid: 770525519
# Processing rivid: 770526518
# Processing rivid: 770527509
# Processing rivid: 770527563
# Processing rivid: 770528527
# Processing rivid: 770528568
# Processing rivid: 770528588
# Processing rivid: 770529598
# Processing rivid: 770530700
# Processing rivid: 770531757
# Processing rivid: 770531760
# Processing rivid: 770532769
# Processing rivid: 770533744
# Processing rivid: 770533811
# Processing rivid: 770533823
# Processing rivid: 770534773
# Processing rivid: 770535817
# Processing rivid: 770535894
# Processing rivid: 770537943
# Processing rivid: 770537960
# Processing rivid: 770538950
# Processing rivid: 770538999
# Processing rivid: 770539014
# Processing rivid: 770540030
# Processing rivid: 770541103
# Processing rivid: 770543115
# Processing rivid: 770545165
# Processing rivid: 770545246
# Processing rivid: 770546225
# Processing rivid: 770547314
# Processing rivid: 770548290
# Processing rivid: 770548306
# Processing rivid: 770549336
# Processing rivid: 770549368
# Processing rivid: 770549384
# Processing rivid: 770549414
# Processing rivid: 770549422
# Processing rivid: 770551468
# Processing rivid: 770552528
# Processing rivid: 770552533
# Processing rivid: 770553578
# Processing rivid: 770554536
# Processing rivid: 770554625
# Processing rivid: 770555570
# Processing rivid: 770556623
# Processing rivid: 770556687
# Processing rivid: 770557729
# Processing rivid: 770558778
# Processing rivid: 770559738
# Processing rivid: 770559755
# Processing rivid: 770560842
# Processing rivid: 770562845
# Processing rivid: 770562848
# Processing rivid: 770562943
# Processing rivid: 770563885
# Processing rivid: 770563902
# Processing rivid: 770563905
# Processing rivid: 770563969
# Processing rivid: 770565985
# Processing rivid: 770566010
# Processing rivid: 770566040
# Processing rivid: 770566050
# Processing rivid: 770567038
# Processing rivid: 770568064
# Processing rivid: 770568068
# Processing rivid: 770568093
# Processing rivid: 770569119
# Processing rivid: 770570201
# Processing rivid: 770571192
# Processing rivid: 770572285
# Processing rivid: 770572288
# Processing rivid: 770572308
# Processing rivid: 770573273
# Processing rivid: 770576396
# Processing rivid: 770576447
# Processing rivid: 770577482
# Processing rivid: 770578531
# Processing rivid: 770580612
# Processing rivid: 770581572
# Processing rivid: 770582661
# Processing rivid: 770583689
# Processing rivid: 770583721
# Processing rivid: 770584755
# Processing rivid: 770585760
# Processing rivid: 770585811
# Processing rivid: 770587878
# Processing rivid: 770587891
# Processing rivid: 770588878
# Processing rivid: 770588884
# Processing rivid: 770589907
# Processing rivid: 770589940
# Processing rivid: 770589963
# Processing rivid: 770590954
# Processing rivid: 770590982
# Processing rivid: 770593043
# Processing rivid: 770593071
# Processing rivid: 770597219
# Processing rivid: 770598243
# Processing rivid: 770598273
# Processing rivid: 770600347
# Processing rivid: 770600349
# Processing rivid: 770601380
# Processing rivid: 770602437
# Processing rivid: 770603456
# Processing rivid: 770603475
# Processing rivid: 770604471
# Processing rivid: 770604503
# Processing rivid: 770605557
# Processing rivid: 770606548
# Processing rivid: 770608632
# Processing rivid: 770609695
# Processing rivid: 770609709
# Processing rivid: 770610761
# Processing rivid: 770611751
# Processing rivid: 770612826
# Processing rivid: 770613847
# Processing rivid: 770613867
# Processing rivid: 770613885
# Processing rivid: 770614887
# Processing rivid: 770616986
# Processing rivid: 770617010
# Processing rivid: 770618001
# Processing rivid: 770619090
# Processing rivid: 770622174
# Processing rivid: 770626338
# Processing rivid: 770626339
# Processing rivid: 770632556
# Processing rivid: 770634658
# Processing rivid: 770636731
# Processing rivid: 770639841
# Processing rivid: 770639856
# Processing rivid: 770642972
# Processing rivid: 770644024
# Processing rivid: 770645056
# Processing rivid: 770647139
# Processing rivid: 770648167
# Processing rivid: 770664812
# Processing rivid: 780000354
# Processing rivid: 780000379
# Processing rivid: 780000736
# Processing rivid: 780000737
# Processing rivid: 780001118
# Processing rivid: 780001119
# Processing rivid: 780001121
# Processing rivid: 780001496
# Processing rivid: 780001497
# Processing rivid: 780001888
# Processing rivid: 780001891
# Processing rivid: 780001895
# Processing rivid: 780002273
# Processing rivid: 780003038
# Processing rivid: 780006059
# Processing rivid: 780007260
# Processing rivid: 780020649
# Processing rivid: 780025608
# Processing rivid: 780029476
# Processing rivid: 780029821
# Processing rivid: 780032160
# Processing rivid: 780032499
# Processing rivid: 780035195
# Processing rivid: 780035203
# Processing rivid: 780037102
# Processing rivid: 780037156
# Processing rivid: 780037875
# Processing rivid: 780039026
# Processing rivid: 780039036
# Processing rivid: 780039812
# Processing rivid: 780040175
# Processing rivid: 780040565
# Processing rivid: 780040584
# Processing rivid: 780040615
# Processing rivid: 780040945
# Processing rivid: 780040949
# Processing rivid: 780040996
# Processing rivid: 780041338
# Processing rivid: 780042127
# Processing rivid: 780042511
# Processing rivid: 780042916
# Processing rivid: 780043257
# Processing rivid: 780043265
# Processing rivid: 780044425
# Processing rivid: 780045172
# Processing rivid: 780045183
# Processing rivid: 780045561
# Processing rivid: 780045950
# Processing rivid: 780047104
# Processing rivid: 780047501
# Processing rivid: 780047525
# Processing rivid: 780047861
# Processing rivid: 780047873
# Processing rivid: 780047907
# Processing rivid: 780047908
# Processing rivid: 780048257
# Processing rivid: 780048647
# Processing rivid: 780049035
# Processing rivid: 780049393
# Processing rivid: 780049444
# Processing rivid: 780049808
# Processing rivid: 780050573
# Processing rivid: 780050591
# Processing rivid: 780050961
# Processing rivid: 780051337
# Processing rivid: 780051339
# Processing rivid: 780051722
# Processing rivid: 780051723
# Processing rivid: 780052106
# Processing rivid: 780052490
# Processing rivid: 780052886
# Processing rivid: 780053652
# Processing rivid: 780054051
# Processing rivid: 780054818
# Processing rivid: 780055205
# Processing rivid: 780055562
# Processing rivid: 780055943
# Processing rivid: 780055948
# Processing rivid: 780055956
# Processing rivid: 780056335
# Processing rivid: 780056721
# Processing rivid: 780057106
# Processing rivid: 780059040
# Processing rivid: 780060194
# Processing rivid: 780060556
# Processing rivid: 780060564
# Processing rivid: 780060575
# Processing rivid: 780060957
# Processing rivid: 780061716
# Processing rivid: 780061727
# Processing rivid: 780062499
# Processing rivid: 780062881
# Processing rivid: 780063631
# Processing rivid: 780064020
# Processing rivid: 780064027
# Processing rivid: 780065953
# Processing rivid: 780065954
# Processing rivid: 780066723
# Processing rivid: 780067103
# Processing rivid: 780067475
# Processing rivid: 780067875
# Processing rivid: 780072476
# Processing rivid: 780077845
# Processing rivid: 780080155
# Processing rivid: 780080539
# Processing rivid: 780087454
# Processing rivid: 780087834
# Processing rivid: 780091673
# Processing rivid: 780092445
# Processing rivid: 780092830
# Processing rivid: 780093981
# Processing rivid: 780093982
# Processing rivid: 780095130
# Processing rivid: 780096280
# Processing rivid: 780098968
# Processing rivid: 780100124
# Processing rivid: 780104732
# Processing rivid: 780105114
# Processing rivid: 780105115
# Processing rivid: 780105500
# Processing rivid: 780106648
# Processing rivid: 780106652
# Processing rivid: 780107032
# Processing rivid: 780108185
# Processing rivid: 780108571
# Processing rivid: 780110105
# Processing rivid: 780112793
# Processing rivid: 780119321

# %% [markdown]
# convert the parquet to zarr

# %%
#ZARR functions
def create_xarray_zarr(melted_df):
    """
    Convert melted DataFrame to xarray Dataset and save as Zarr
    
    Parameters:
    melted_df (pd.DataFrame): Melted DataFrame with columns 'rivid', 'Month', 'p_exceed', 'fdc'
    """
    # Ensure proper data types
    melted_df = melted_df.copy()
    melted_df['Month'] = melted_df['Month'].astype(int)
    melted_df['p_exceed'] = melted_df['p_exceed'].astype(int)
    
    # Sort values to ensure consistent ordering
    melted_df = melted_df.sort_values(['rivid', 'p_exceed', 'Month'])
    
    # Get unique values for dimensions
    gauges = sorted(melted_df['rivid'].unique())
    p_exceed_values = sorted(melted_df['p_exceed'].unique())
    months = sorted(melted_df['Month'].unique())
    
    # Create 3D array with proper shape
    shape = (len(gauges), len(p_exceed_values), len(months))
    data = np.full(shape, np.nan)
    
    # Create lookup dictionaries for faster indexing
    gauge_idx = {g: i for i, g in enumerate(gauges)}
    p_idx = {p: i for i, p in enumerate(p_exceed_values)}
    month_idx = {m: i for i, m in enumerate(months)}
    
    # Fill the 3D array
    for _, row in melted_df.iterrows():
        i = gauge_idx[row['rivid']]
        j = p_idx[row['p_exceed']]
        k = month_idx[row['Month']]
        data[i, j, k] = row['fdc']
    
    # Create xarray Dataset
    ds = xr.Dataset(
        {
            'fdc': (['rivid', 'p_exceed', 'month'], data)
        },
        coords={
            'rivid': gauges,
            'p_exceed': p_exceed_values,
            'month': months
        }
    )
    
    # Chunk the dataset - adjust chunk sizes based on your needs
    ds = ds.chunk({
        'rivid': min(50, len(gauges)),
        'p_exceed': min(101, len(p_exceed_values)),
        'month': min(12, len(months))
    })
    
    return ds

def save_to_zarr(ds, filename='/Users/yubinbaaniya/Documents/WORLD BIAS/saber workdir/simulated_monthly_fdc.zarr'):  #the file path is hardcoded here
    """
    Save xarray Dataset to Zarr format and return the absolute path
    
    Parameters:
    ds (xarray.Dataset): Dataset to save
    filename (str): Output filename with path
    
    Returns:
    str: Absolute path to the saved Zarr file
    """
    # Convert to absolute path
    abs_path = os.path.abspath(filename)
    
    # Save to Zarr format without compression
    ds.to_zarr(abs_path, mode='w')
    
    print(f"Zarr file saved to: {abs_path}")
    return abs_path


#Function Call to make a zarr file
ds = create_xarray_zarr(melted_df)
zarr_path = save_to_zarr(ds)
# Out:
# Zarr file saved to: /Users/yubinbaaniya/Documents/WORLD BIAS/saber workdir/simulated_monthly_fdc.zarr
